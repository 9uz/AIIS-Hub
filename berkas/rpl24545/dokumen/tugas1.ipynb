# %% [markdown]
# # Tugas Praktikum: Eksplorasi Data Mandiri & Analisis Spesifik
#
# **Nama Mahasiswa:** [Tulis Nama Lengkap]
#
# **NIM:** [Tulis NIM Lengkap - Hanya Angka]
#
# ---
# ## 📌 Ketentuan & Kriteria Ketat Dataset UCI
# Cari dataset secara mandiri di [UCI Machine Learning Repository](https://archive.ics.uci.edu/datasets) yang memenuhi kriteria wajib berikut:
# 1. **Ukuran Data:** Minimal **1.000 baris (instances)** dan minimal **10 kolom (features)**.
# 2. **Variasi Tipe Data:** Wajib memiliki kombinasi data **Numerik** (int/float) dan **Kategorikal** (object/string/category).
# 3. **Kondisi Data:** Dataset **WAJIB memuat missing values (nilai kosong/NaN)**. Jangan memilih dataset yang sudah 100% bersih.
# 4. **Validasi Anti-Plagiat:** Setiap mahasiswa WAJIB menggunakan dataset dengan ID UCI yang berbeda dari teman sekelompok/seangkatan.

# %% [markdown]
# ### 0. Inisialisasi Environment & Input Identitas
# Jalankan sel ini. Pastikan Anda memasukkan 3 digit terakhir NIM Anda pada variabel `NIM_AKHIR`.

# %%
# !pip install ucimlrepo -q

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from ucimlrepo import fetch_ucirepo

sns.set_theme(style="whitegrid")

# ========================================================
# UBAH DUA VARIABEL DI BAWAH INI SEESUAI DATA ANDA
ID_DATASET_UCI = 0   # Ganti dengan ID dataset UCI pilihan Anda
NIM_AKHIR = 000       # Ganti dengan 3 digit terakhir NIM Anda (misal: 042)
# ========================================================

print(f"ID Dataset: {ID_DATASET_UCI}")
print(f"Faktor Pengacak NIM: {NIM_AKHIR}")

# %% [markdown]
# ### Bagian 1: Pengambilan & Data Cleaning Terverifikasi
# 1. Ambil dataset menggunakan `fetch_ucirepo(id=ID_DATASET_UCI)`.
# 2. Tampilkan jumlah baris dan kolom menggunakan `.shape`. **(Ingat: Min 1000 baris, 10 kolom)**.
# 3. Tampilkan jumlah *missing values* per kolom dengan `.isnull().sum()`.
# 4. Terapkan strategi penanganan *missing value* (hapus baris dengan `.dropna()` ATAU isi nilai kosong dengan `.fillna()`).

# %%
# Tulis kode Bagian 1 di sini

# %% [markdown]
# ##### 📝 Justifikasi Pembersihan Data (Wajib Diisi)
# *Jelaskan alasan teknis mengapa Anda memilih metode cleaning di atas (kenapa memilih fillna/dropna pada kolom tertentu)?*
#
# **Jawaban:**

# %% [markdown]
# # Tulis Jawaban disini

# %% [markdown]
# ### Bagian 2: Manipulasi Data Dinamis
# 1. **Buat Feature baru** Buat kolom baru bernama `Fitur_Dinamis`. Nilainya adalah hasil perkalian salah satu kolom numerik di data Anda dengan rumus:
#    $$\text{Fitur\_Dinamis} = \text{Kolom\_Numerik\_Pilihan} \times \left(1 + \frac{\text{NIM\_AKHIR}}{100}\right)$$
# 2. **Filtering:** Saring data sehingga hanya menampilkan baris yang nilai `Fitur_Dinamis`-nya di atas rata-rata (`.mean()`).
# 3. **Agregasi Multi-Kategori:** Gunakan `.groupby()` pada satu kolom kategorikal untuk menghitung nilai `.mean()` dan `.std()` dari `Fitur_Dinamis`.

# %%
# Tulis kode Bagian 2 di sini

# %% [markdown]
# ### Bagian 3: Restrukturisasi & Join Data
# 1. Bagi `df` Anda menjadi dua DataFrame terpisah secara kolom:
#    - `df_kategori`: Berisi kolom-kolom kategorikal + indeks data.
#    - `df_numerik`: Berisi kolom-kolom numerik + `Fitur_Dinamis` + indeks data.
# 2. Lakukan penggabungan data kembali menggunakan `pd.merge()` berdasarkan indeks masing-masing (`left_index=True, right_index=True`). Tampilkan 5 baris pertama hasil merge.

# %%
# Tulis kode Bagian 3 di sini

# %% [markdown]
# ### Bagian 4: Visualisasi Data (Format Cetak PDF)
# Buat **dua grafik statis** menggunakan `seaborn` atau `matplotlib`:
# 1. **Grafik 1 (Distribusi):** Histogram atau Boxplot dari `Fitur_Dinamis`.
# 2. **Grafik 2 (Hubungan/Korelasi):** Scatterplot atau Barplot yang membandingkan kolom kategorikal dengan `Fitur_Dinamis`.
# *Sertakan judul grafik, label sumbu X dan Y, serta legenda yang jelas.*

# %%
# Tulis kode Bagian 4 di sini

# %% [markdown]
# ### 💡 Analisis Temuan & Interpretasi
# Sebutkan **dua temuan utama** dari visualisasi di atas yang dihubungkan langsung dengan konteks domain dataset yang Anda pilih!
#
# **Jawaban:**
# 1. ##### Tulis Disini
# 2. ##### Tulis Disini
#
# ---
# ## 🖨️ Panduan Ekspor ke PDF
# 1. Pastikan seluruh sel telah dieksekusi dan output angka/grafik terlihat jelas.
# 2. Tekan **Ctrl + P** (Windows) atau **Cmd + P** (Mac) pada browser Anda.
# 3. Ubah *Destination/Printer* menjadi **Save as PDF**.
# 4. Pastikan bagian header (Nama & NIM) di halaman pertama tercetak dengan jelas.
