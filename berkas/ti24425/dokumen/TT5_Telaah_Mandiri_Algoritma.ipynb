# %% [markdown]
# # Tugas Terstruktur 5
#
# ## Telaah Mandiri Algoritma, Rencana Belajar, dan Refleksi
#
# **Mata Kuliah** Data Science (TI24425) &middot; 3 sks (Teori)
# **Program Studi** Teknologi Informasi &middot; Politeknik Negeri Madiun
# **Semester** Genap &middot; Tahun Akademik 2026/2027
# **Cakupan materi** Di luar materi kuliah &middot; mengukur **CPMK081** (pembelajaran sepanjang hayat)
# **Bobot** 4% dari nilai akhir
# **Bentuk** Telaah kelompok, refleksi perorangan &middot; diberikan pada pertemuan 13
#
# ---
#
# ### Identitas Kelompok
#
# | | Nama Lengkap | NPM | Bagian yang Dikerjakan |
# |---|---|---|---|
# | 1 | | | Bagian A, dan Bagian D.1 |
# | 2 | | | Bagian B, dan Bagian D.2 |
# | 3 | | | Bagian C, dan Bagian D.3 |
#
# | | |
# |---|---|
# | **Kelas** | |
# | **Algoritma yang diundi** | |
# | **Tanggal Presentasi Kilat** | |
# | **Tanggal pengumpulan** | |

# %% [markdown]
# ---
#
# ## Petunjuk Pengerjaan
#
# ### Apa yang berbeda pada tugas ini
#
# Tugas ini **tidak menguji penguasaan materi kuliah**. Yang diukur adalah kemampuan Anda **mempelajari sesuatu yang belum pernah diajarkan**, secara mandiri, dari sumber primer. Karena itu:
#
# - Algoritma yang ditelaah **berada di luar** materi pertemuan 1 sampai 13.
# - Bagian A sampai C dikerjakan **bersama** sebagai kelompok, karena menjadi bahan Presentasi Kilat.
# - Bagian D dikerjakan **sendiri-sendiri oleh tiap anggota**. Tidak boleh disamakan. Bagian inilah yang secara khusus mengukur CPMK081.
#
# ### Sumber yang wajib dipakai
#
# Sekurang-kurangnya **dua sumber primer**, yaitu:
#
# - Dokumentasi resmi, misalnya *scikit-learn User Guide*, dan
# - Salah satu dari: buku teks (ISL atau ESL), catatan kuliah CS 189, atau makalah asli algoritma tersebut.
#
# **Ringkasan sekunder tidak dihitung** sebagai sumber primer: blog, video tutorial, rangkuman di media sosial, dan keluaran AI generatif.
#
# ### Daftar algoritma
#
# Sesi 2 Presentasi Kilat: K-Means &middot; Hierarchical Clustering &middot; Agglomerative Clustering &middot; HDBSCAN &middot; Principal Component Analysis &middot; Gaussian Processes &middot; Isotonic Regression &middot; Neural Network Models.
#
# Kelompok mengerjakan algoritma yang **diundi**, bukan yang dipilih sendiri.
#
# ### Menyimpan sebagai PDF
#
# Jalankan seluruh sel (**Run &rarr; Run All Cells**), lalu **File &rarr; Print** dan pilih **Save as PDF**. Beri nama `TT5_<Kelas>_<NamaKelompok>.pdf`.
#
# ### Penggunaan AI generatif
#
# Diperbolehkan untuk **menemukan istilah** dan **memeriksa pemahaman**, tetapi **tidak** untuk menulis Bagian B dan Bagian D. Bagian D adalah refleksi pribadi; keluaran AI di bagian itu diperlakukan sebagai pelanggaran akademik. Cantumkan seluruh penggunaan pada Lampiran.

# %% [markdown]
# ---
# ---
#
# # Bagian A &mdash; Identitas Algoritma dan Sumber
#
# **Dikerjakan bersama.**

# %% [markdown]
# ## A.1 Identitas
#
# | Butir | Isian |
# |---|---|
# | Nama algoritma | |
# | Nama lain atau singkatan yang dipakai | |
# | Termasuk supervised atau unsupervised? | |
# | Bentuk masalah yang diselesaikan | |
# | Tahun dan penemu pertama, bila diketahui | |
# | Nama kelas pada scikit-learn | |
#
# ## A.2 Sumber yang Dipakai
#
# | No | Jenis sumber | Judul dan penulis | Tautan | Bagian mana yang Anda pakai |
# |---|---|---|---|---|
# | 1 | Dokumentasi resmi | | | |
# | 2 | Buku teks / catatan kuliah / makalah | | | |
# | 3 | (opsional) | | | |
#
# **[URAIAN A.1]** Jelaskan proses pencarian Anda: sumber apa yang pertama kali Anda temukan, mengapa sumber itu **tidak** Anda pakai sebagai rujukan utama, dan bagaimana akhirnya Anda sampai pada sumber primer di atas.
#
# > _Tulis jawaban Anda di sini._

# %% [markdown]
# ---
# ---
#
# # Bagian B &mdash; Telaah Algoritma
#
# **Dikerjakan bersama.** Bagian ini mengikuti lima butir struktur wajib Presentasi Kilat.
#
# > **Aturan penting.** Seluruh bagian ini harus ditulis **dengan bahasa Anda sendiri**. Menyalin kalimat dari dokumentasi, meskipun sumbernya dicantumkan, tidak memperoleh nilai. Yang diuji adalah pemahaman, bukan kemampuan menyalin.

# %% [markdown]
# ## B.1 Prinsip Kerja
#
# **[URAIAN B.1]** Jelaskan cara kerja algoritma ini dalam **tiga sampai lima langkah berurutan**, seolah menjelaskannya kepada teman seangkatan yang belum pernah mendengarnya. Hindari istilah yang tidak Anda pahami sendiri.
#
# | Langkah | Yang dikerjakan algoritma |
# |---|---|
# | 1 | |
# | 2 | |
# | 3 | |
# | 4 | |
# | 5 | |
#
# > _Tulis penjelasan tambahan Anda di sini._
#
# ## B.2 Asumsi yang Mendasari
#
# **[URAIAN B.2]** Setiap algoritma membawa asumsi. Sebutkan **dua sampai tiga asumsi** yang mendasari algoritma ini, dan untuk masing-masing jelaskan apa yang terjadi bila asumsi itu tidak terpenuhi.
#
# | Asumsi | Akibat bila tidak terpenuhi |
# |---|---|
# | | |
# | | |
# | | |
#
# > _Tulis jawaban Anda di sini._
#
# ## B.3 Kelebihan dan Keterbatasan
#
# **[URAIAN B.3]** Isi keduanya secara seimbang. Daftar keterbatasan yang lebih pendek daripada daftar kelebihan biasanya menandakan telaah yang belum selesai.
#
# | Kelebihan | Keterbatasan |
# |---|---|
# | | |
# | | |
# | | |
#
# ## B.4 Kapan Tepat Digunakan
#
# **[URAIAN B.4]** Jawab dua pertanyaan berikut.
#
# 1. Sebutkan **dua keadaan** ketika algoritma ini merupakan pilihan yang tepat, beserta alasannya.
# 2. Sebutkan **satu keadaan** ketika algoritma ini justru **keliru** dipakai, dan apa yang sebaiknya dipakai sebagai gantinya.
#
# > _Tulis jawaban Anda di sini._
#
# ## B.5 Satu Contoh Penerapan Nyata
#
# **[URAIAN B.5]** Uraikan satu penerapan nyata yang Anda temukan dari sumber, bukan yang Anda karang. Sebutkan: bidangnya, masalah yang dipecahkan, dan mengapa algoritma ini yang dipilih di sana.
#
# > _Tulis jawaban Anda di sini._
#
# ## B.6 Kaitan dengan Materi Kuliah
#
# **[URAIAN B.6]** Hubungkan algoritma ini dengan **dua konsep** yang sudah dipelajari pada pertemuan 1 sampai 13. Contoh kaitan yang mungkin: ruang hipotesis, bias induktif, kebutuhan penskalaan, hyperparameter, atau cara evaluasinya.
#
# | Konsep dari kuliah | Pertemuan | Bagaimana kaitannya |
# |---|---|---|
# | | | |
# | | | |

# %% [markdown]
# ---
# ---
#
# # Bagian C &mdash; Percobaan Singkat
#
# **Dikerjakan bersama.** Bagian ini **opsional dan menjadi nilai tambah**, bukan syarat kelulusan tugas.
#
# Bila kelompok Anda mengerjakannya, jalankan algoritma tersebut pada dataset kelompok Anda dan tafsirkan hasilnya. Bila tidak, isi uraian pada C.2 dengan penjelasan **rancangan** percobaan yang akan Anda lakukan seandainya ada waktu.

# %%
# [KODE] Opsional — sesuaikan dengan algoritma yang Anda telaah
# Contoh kerangka; ganti bagian yang ditandai.
import pandas as pd, numpy as np, matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# df = pd.read_csv('nama_berkas_dataset.csv')
# X_num = df.select_dtypes(include=[np.number]).dropna()
# Xs = StandardScaler().fit_transform(X_num)

# from sklearn.____ import ____        # ganti dengan kelas algoritma Anda
# model = ____(...)                     # ganti dengan parameter yang sesuai
# hasil = model.fit(Xs)

print('Sel ini opsional. Hapus tanda pagar dan lengkapi bila kelompok Anda mengerjakannya.')

# %% [markdown]
# **[URAIAN C.1]** Bila Anda menjalankan percobaan: jelaskan apa yang Anda jalankan, hyperparameter apa yang Anda tetapkan dan mengapa, serta apa yang terlihat dari hasilnya.
#
# **[URAIAN C.2]** Bila Anda **tidak** menjalankan percobaan: uraikan rancangan percobaan yang akan Anda lakukan — data apa yang dipakai, hyperparameter apa yang perlu ditetapkan, dan bagaimana hasilnya akan dinilai. Rancangan yang jelas tetap memperoleh nilai.
#
# > _Tulis jawaban Anda di sini._

# %% [markdown]
# ---
# ---
#
# # Bagian D &mdash; Rencana Belajar Mandiri dan Refleksi
#
# **Dikerjakan sendiri-sendiri oleh tiap anggota. Jawaban ketiganya tidak boleh sama.**
#
# Bagian ini yang secara khusus mengukur **CPMK081**: kemampuan mengenali kebutuhan belajar sendiri dan menyusun rencana pembelajaran mandiri. Kejujuran dinilai lebih tinggi daripada kesan pandai.

# %% [markdown]
# ## D.1 &mdash; Anggota 1
#
# **Nama:** ______________________  **NPM:** ______________________
#
# ### D.1.1 Kesenjangan pengetahuan yang saya temukan
#
# **[URAIAN]** Sebutkan **dua hal** yang ternyata belum Anda kuasai dan baru Anda sadari saat mengerjakan telaah ini. Sebutkan secara spesifik — jawaban seperti “masih kurang matematika” tidak memperoleh nilai.
#
# | No | Hal yang belum saya kuasai | Bagaimana saya menyadarinya |
# |---|---|---|
# | 1 | | |
# | 2 | | |
#
# ### D.1.2 Rencana belajar mandiri saya
#
# **[URAIAN]** Susun rencana **empat minggu ke depan**. Setiap baris wajib memuat indikator keberhasilan yang dapat diperiksa — bukan sekadar “memahami lebih dalam”.
#
# | Minggu | Yang akan saya pelajari | Sumber yang akan saya pakai | Indikator keberhasilan |
# |---|---|---|---|
# | 1 | | | |
# | 2 | | | |
# | 3 | | | |
# | 4 | | | |
#
# ### D.1.3 Refleksi
#
# **[URAIAN]** Jawab ketiga pertanyaan berikut, masing-masing dua sampai empat kalimat.
#
# 1. Apa bagian **tersulit** dari mempelajari sesuatu tanpa diajarkan lebih dulu, dan bagaimana Anda mengatasinya?
# 2. Cara belajar apa yang **ternyata tidak berhasil** untuk Anda pada tugas ini? Jelaskan mengapa.
# 3. Bila enam bulan lagi Anda harus mempelajari algoritma baru lainnya secara mandiri, apa **satu hal** yang akan Anda lakukan berbeda?
#
# > _Tulis jawaban Anda di sini._
#
# ---

# %% [markdown]
# ## D.2 &mdash; Anggota 2
#
# **Nama:** ______________________  **NPM:** ______________________
#
# ### D.2.1 Kesenjangan pengetahuan yang saya temukan
#
# **[URAIAN]** Sebutkan **dua hal** yang ternyata belum Anda kuasai dan baru Anda sadari saat mengerjakan telaah ini. Sebutkan secara spesifik — jawaban seperti “masih kurang matematika” tidak memperoleh nilai.
#
# | No | Hal yang belum saya kuasai | Bagaimana saya menyadarinya |
# |---|---|---|
# | 1 | | |
# | 2 | | |
#
# ### D.2.2 Rencana belajar mandiri saya
#
# **[URAIAN]** Susun rencana **empat minggu ke depan**. Setiap baris wajib memuat indikator keberhasilan yang dapat diperiksa — bukan sekadar “memahami lebih dalam”.
#
# | Minggu | Yang akan saya pelajari | Sumber yang akan saya pakai | Indikator keberhasilan |
# |---|---|---|---|
# | 1 | | | |
# | 2 | | | |
# | 3 | | | |
# | 4 | | | |
#
# ### D.2.3 Refleksi
#
# **[URAIAN]** Jawab ketiga pertanyaan berikut, masing-masing dua sampai empat kalimat.
#
# 1. Apa bagian **tersulit** dari mempelajari sesuatu tanpa diajarkan lebih dulu, dan bagaimana Anda mengatasinya?
# 2. Cara belajar apa yang **ternyata tidak berhasil** untuk Anda pada tugas ini? Jelaskan mengapa.
# 3. Bila enam bulan lagi Anda harus mempelajari algoritma baru lainnya secara mandiri, apa **satu hal** yang akan Anda lakukan berbeda?
#
# > _Tulis jawaban Anda di sini._
#
# ---

# %% [markdown]
# ## D.3 &mdash; Anggota 3
#
# **Nama:** ______________________  **NPM:** ______________________
#
# ### D.3.1 Kesenjangan pengetahuan yang saya temukan
#
# **[URAIAN]** Sebutkan **dua hal** yang ternyata belum Anda kuasai dan baru Anda sadari saat mengerjakan telaah ini. Sebutkan secara spesifik — jawaban seperti “masih kurang matematika” tidak memperoleh nilai.
#
# | No | Hal yang belum saya kuasai | Bagaimana saya menyadarinya |
# |---|---|---|
# | 1 | | |
# | 2 | | |
#
# ### D.3.2 Rencana belajar mandiri saya
#
# **[URAIAN]** Susun rencana **empat minggu ke depan**. Setiap baris wajib memuat indikator keberhasilan yang dapat diperiksa — bukan sekadar “memahami lebih dalam”.
#
# | Minggu | Yang akan saya pelajari | Sumber yang akan saya pakai | Indikator keberhasilan |
# |---|---|---|---|
# | 1 | | | |
# | 2 | | | |
# | 3 | | | |
# | 4 | | | |
#
# ### D.3.3 Refleksi
#
# **[URAIAN]** Jawab ketiga pertanyaan berikut, masing-masing dua sampai empat kalimat.
#
# 1. Apa bagian **tersulit** dari mempelajari sesuatu tanpa diajarkan lebih dulu, dan bagaimana Anda mengatasinya?
# 2. Cara belajar apa yang **ternyata tidak berhasil** untuk Anda pada tugas ini? Jelaskan mengapa.
# 3. Bila enam bulan lagi Anda harus mempelajari algoritma baru lainnya secara mandiri, apa **satu hal** yang akan Anda lakukan berbeda?
#
# > _Tulis jawaban Anda di sini._
#
# ---

# %% [markdown]
# # Bahan Presentasi Kilat
#
# **Dikerjakan bersama.** Durasi 5–7 menit di kelas pada pertemuan 13.
#
# | Butir | Poin yang akan disampaikan | Siapa yang menyampaikan | Perkiraan durasi |
# |---|---|---|---|
# | 1. Prinsip kerja | | | |
# | 2. Asumsi yang mendasari | | | |
# | 3. Kelebihan dan keterbatasan | | | |
# | 4. Kapan tepat digunakan | | | |
# | 5. Satu contoh penerapan nyata | | | |
#
# **[URAIAN]** Tuliskan **satu kalimat penutup** yang ingin kelompok Anda tinggalkan di benak pendengar setelah presentasi selesai.
#
# > _Tulis jawaban Anda di sini._

# %% [markdown]
# ---
#
# # Lampiran &mdash; Pernyataan Penggunaan AI Generatif
#
# | Bagian yang dibantu | Nama alat | Bentuk bantuan | Cara kami memverifikasi |
# |---|---|---|---|
# | | | | |
# | | | | |
#
# Dengan ini kami menyatakan bahwa seluruh analisis, justifikasi, dan kesimpulan dalam berkas ini merupakan hasil penalaran kelompok kami sendiri, dan seluruh bantuan alat AI generatif telah kami cantumkan secara jujur.
#
# | Anggota 1 | Anggota 2 | Anggota 3 |
# |---|---|---|
# | ( ......................... ) | ( ......................... ) | ( ......................... ) |

# %% [markdown]
# ---
#
# # Rubrik Penilaian
#
# Mengacu pada **Lampiran 3b RPS — Rubrik Belajar Mandiri**. Total 100 poin, dikonversi menjadi bobot 4% pada nilai akhir.
#
# | Kriteria | Deskriptor capaian penuh | Poin |
# |---|---|---|
# | **Relevansi topik eksplorasi** | Topik berada di luar materi kuliah, mutakhir, dan relevan dengan bidang Teknologi Informasi | 20 |
# | **Kedalaman penelusuran sumber** | Memakai sekurang-kurangnya dua sumber primer yang kredibel, bukan ringkasan sekunder | 25 |
# | **Kualitas pemahaman yang disampaikan** | Mampu menjelaskan prinsip kerja, asumsi, dan keterbatasan dengan bahasa sendiri | 25 |
# | **Kualitas rencana belajar mandiri** | Rencana spesifik, bertahap, realistis, dan disertai indikator keberhasilan yang dapat diperiksa | 20 |
# | **Kualitas refleksi** | Mengidentifikasi kesenjangan pengetahuan diri secara jujur dan spesifik | 10 |
# | | **Jumlah** | **100** |
#
# ### Ketentuan penilaian
#
# - **Kalimat yang disalin dari sumber tidak memperoleh nilai**, sekalipun sumbernya dicantumkan. Yang diuji adalah pemahaman.
# - **Bagian D yang isinya sama antar-anggota dinilai nol** untuk ketiganya. Refleksi bersifat pribadi.
# - Rencana belajar tanpa **indikator keberhasilan** yang dapat diperiksa memperoleh separuh poin.
# - Daftar keterbatasan yang jauh lebih pendek daripada daftar kelebihan menandakan telaah yang belum selesai, dan mengurangi nilai kriteria ketiga.
# - Percobaan pada Bagian C bersifat **opsional** dan dapat menambah maksimal 5 poin, dengan nilai akhir tetap dibatasi 100.
# - Keterlambatan dikenakan pengurangan 10% nilai per hari kerja, maksimal tiga hari kerja.
#
# ### Kaitan dengan capaian pembelajaran
#
# Tugas ini adalah asesmen utama bagi **CPMK081**: *mampu mengidentifikasi kebutuhan belajarnya sendiri dan menyusun rencana pembelajaran mandiri untuk terus meningkatkan pengetahuan dan keterampilan di bidang teknologi informasi.* Bagian D memberi bobot 30 poin, terbesar setelah kedalaman sumber dan kualitas pemahaman.
